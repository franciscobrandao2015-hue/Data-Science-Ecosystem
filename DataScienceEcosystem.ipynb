# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# - In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ___Objectives:___
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Recognize open-source development environments and tools for Data Science
# - Demonstrate simple arithmetic operations in Python
# - Convert units using Python expressions (e.g., minutes to hours)

# %% [markdown]
# - Some of the popular languages that Data Scientists use are:
#     1. Python
#     2. R
#     3. Java
#     4. SQL
#     5. Julia
#     6. Scala

# %% [markdown]
# - Some of the commonly used libraries used by Data Scientists include:
#     1. NumPy (Python)
#     2. Pandas (Python)
#     3. tidyverse (R)
#     4. ggplot2 (R)
#     5. Scikit-learn (Python)
#     6. dplyr (R)

# %% [markdown]
# |Data Science Tools|
# |:----------------:|
# |VS Code (Visual Studio Code)|
# |RStudio|
# |Jupyter Notebook|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author:
# Francisco Brandão
